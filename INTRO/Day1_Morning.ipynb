# %% [markdown]
# These are the materials from Monday morning of the astropy workshop.

# %%
w_kg = 60

# %%
Test=10
test=20

# %%
w_kg = 60.

# %%
w_kg_text = 'weight in kg'

# %%
print('weight in pounds', w_kg*2.2)
# Out:
# weight in pounds 132.0

# %%
print(w_kg)
# Out:
# 60

# %%
w_kg
# Out:
# 100

# %%
w_lb = w_kg*2.2

# %%
print('weight in pounds:', w_lb, 'weight in kg: ', w_kg)
# Out:
# weight in pounds: 220.00000000000003 weight in kg:  60.0

# %%
w_kg = 200
print('weight in pounds: ', w_lb, 'weight in kg: ', w_kg)
# Out:
# weight in pounds:  220.00000000000003 weight in kg:  200

# %%
# !wget --no-check-certificate 'http://tinyurl.com/astropyday1data' -O foo.tar
# Out:
# --2023-11-20 07:41:17--  http://tinyurl.com/astropyday1data
# Resolving tinyurl.com (tinyurl.com)... 104.20.139.65, 172.67.1.225, 104.20.138.65, ...
# Connecting to tinyurl.com (tinyurl.com)|104.20.139.65|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://docs.google.com/uc?export=download&id=1G7NCnPwoTmmweqyqmZ1RnnAcEUI_rgHQ [following]
# --2023-11-20 07:41:17--  https://docs.google.com/uc?export=download&id=1G7NCnPwoTmmweqyqmZ1RnnAcEUI_rgHQ
# Resolving docs.google.com (docs.google.com)... 142.251.16.100, 142.251.16.139, 142.251.16.113, ...
# Connecting to docs.google.com (docs.google.com)|142.251.16.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-3k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/eadcuo7kuqnj3cmi6q4r02tdpghobhij/1700466075000/17278011755076704091/*/1G7NCnPwoTmmweqyqmZ1RnnAcEUI_rgHQ?e=download&uuid=6caaed43-81c2-48e3-b60b-008b6ff4a29b [following]
# Warning: wildcards not supported in HTTP.
# --2023-11-20 07:41:18--  https://doc-0o-3k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/eadcuo7kuqnj3cmi6q4r02tdpghobhij/1700466075000/17278011755076704091/*/1G7NCnPwoTmmweqyqmZ1RnnAcEUI_rgHQ?e=download&uuid=6caaed43-81c2-48e3-b60b-008b6ff4a29b
# Resolving doc-0o-3k-docs.googleusercontent.com (doc-0o-3k-docs.googleusercontent.com)... 142.250.31.132, 2607:f8b0:4004:c0b::84
# Connecting to doc-0o-3k-docs.googleusercontent.com (doc-0o-3k-docs.googleusercontent.com)|142.250.31.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90112 (88K) [application/x-tar]
# Saving to: ‘foo.tar’
#
# foo.tar             100%[===================>]  88.00K  --.-KB/s    in 0.009s
#
# 2023-11-20 07:41:18 (9.56 MB/s) - ‘foo.tar’ saved [90112/90112]

# %%
# !tar -xvf foo.tar
# Out:
# astropy_day1_data/
# astropy_day1_data/._03D1au.csv
# astropy_day1_data/03D1au.csv
# astropy_day1_data/._03D1aw.csv
# astropy_day1_data/03D1aw.csv
# astropy_day1_data/._03D1bm.csv
# astropy_day1_data/03D1bm.csv
# astropy_day1_data/._03D1cm.csv
# astropy_day1_data/03D1cm.csv
# astropy_day1_data/._.DS_Store
# astropy_day1_data/.DS_Store
# astropy_day1_data/._03D1bk.csv
# astropy_day1_data/03D1bk.csv
# astropy_day1_data/._03D1co.csv
# astropy_day1_data/03D1co.csv
# astropy_day1_data/._03D1ar_r.csv
# astropy_day1_data/03D1ar_r.csv
# astropy_day1_data/._03D1ar_g.csv
# astropy_day1_data/03D1ar_g.csv
# astropy_day1_data/._03D1dj.csv
# astropy_day1_data/03D1dj.csv
# astropy_day1_data/._03D1ar_z.csv
# astropy_day1_data/03D1ar_z.csv
# astropy_day1_data/._03D1ar_i.csv
# astropy_day1_data/03D1ar_i.csv
# astropy_day1_data/._03D1bp.csv
# astropy_day1_data/03D1bp.csv
# astropy_day1_data/._03D1ax.csv
# astropy_day1_data/03D1ax.csv

# %%
# !mv astropy_day1_data data

# %%
ls data
# Out:
# 03D1ar_g.csv  03D1ar_r.csv  03D1au.csv  03D1ax.csv  03D1bm.csv  03D1cm.csv  03D1dj.csv
# 03D1ar_i.csv  03D1ar_z.csv  03D1aw.csv  03D1bk.csv  03D1bp.csv  03D1co.csv

# %%
import numpy

# %%
data = numpy.loadtxt(fname='data/03D1ar_i.csv',delimiter=',',skiprows=1)

# %%
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
data.dtype
# Out:
# dtype('float64')

# %%
data.shape
# Out:
# (22, 3)

# %%
print("first value in data array: ", data[0,0])
# Out:
# first value in data array:  52881.5

# %%
print("another value in data array: ", data[21,2])
# Out:
# another value in data array:  20.277

# %%
print(data[0:9,0:2])
# Out:
# [[5.28815e+04 1.61570e+01]
#  [5.28866e+04 1.89440e+02]
#  [5.29005e+04 6.54020e+02]
#  [5.29045e+04 6.94110e+02]
#  [5.29086e+04 6.04660e+02]
#  [5.29124e+04 5.70830e+02]
#  [5.29156e+04 5.06010e+02]
#  [5.29294e+04 2.75090e+02]
#  [5.29334e+04 2.64740e+02]]

# %%
print(data[2:7,1:2])
# Out:
# [[654.02]
#  [694.11]
#  [604.66]
#  [570.83]
#  [506.01]]

# %%
small = data[:4,1:]
print('small is: ', small)
# Out:
# small is:  [[ 16.157  18.629]
#  [189.44   19.855]
#  [654.02   23.202]
#  [694.11   17.71 ]]

# %%
double = small*2
print(double)
# Out:
# [[  32.314   37.258]
#  [ 378.88    39.71 ]
#  [1308.04    46.404]
#  [1388.22    35.42 ]]

# %%
tripple = small + double
print(tripple)
# Out:
# [[  48.471   55.887]
#  [ 568.32    59.565]
#  [1962.06    69.606]
#  [2082.33    53.13 ]]

# %%
numpy.mean(small)
# Out:
# 204.14037499999998

# %%
numpy.max(small)
# Out:
# 694.11

# %%
numpy.std(small)
# Out:
# 277.0122539432766

# %%
numpy.maximum([1,2,3], [3,2,1])
# Out:
# array([3, 2, 3])

# %%
index = data[:,1] > 100
print(index)
# Out:
# [False  True  True  True  True  True  True  True  True  True  True  True
#  False  True  True False False False False False False False]

# %%
numpy.sum(index)
# Out:
# 13

# %%
print(data[index])
# Out:
# [[5.28866e+04 1.89440e+02 1.98550e+01]
#  [5.29005e+04 6.54020e+02 2.32020e+01]
#  [5.29045e+04 6.94110e+02 1.77100e+01]
#  [5.29086e+04 6.04660e+02 2.04640e+01]
#  [5.29124e+04 5.70830e+02 1.95730e+01]
#  [5.29156e+04 5.06010e+02 2.51400e+01]
#  [5.29294e+04 2.75090e+02 3.12060e+01]
#  [5.29334e+04 2.64740e+02 1.63790e+01]
#  [5.29374e+04 1.90610e+02 1.57770e+01]
#  [5.29424e+04 1.54800e+02 2.44570e+01]
#  [5.29443e+04 1.62780e+02 1.98010e+01]
#  [5.29643e+04 1.04970e+02 2.18940e+01]
#  [5.29722e+04 1.32510e+02 3.50200e+01]]

# %%
numpy.zeros([5,2])+3.5
# Out:
# array([[3.5, 3.5],
#        [3.5, 3.5],
#        [3.5, 3.5],
#        [3.5, 3.5],
#        [3.5, 3.5]])

# %%
numpy.isnan(data[:,1])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
image = plt.imshow(data[:,1:])

# %%
mjd = data[:,0]
flux = data[:,1]
plt.plot(mjd, flux)
plt.plot(mjd, flux, 'o', color='#f2aeb4')
plt.xlabel('Modified JD')
plt.ylabel('i Flux')
plt.ylim([0,800])
# Out:
# (0.0, 800.0)
